# %% [markdown]
# ### OT 내용 정리

# %% [markdown]
# 선수 과목 - 데이터과학, 파이썬, R, 회귀, 수통, 선형대수
#
# 데이터 과학에서는 회귀분석, lasso, 리지, 로지스틱 딥뉴럴네트워크(DNN) 등을 배웠다.
#
# 텐서플로우 - 케라스 (구글이 만듬)

# %% [markdown]
# 이미지 자료분석
# 추천시스템
# 시퀀스자료분석
# 생성모형
#
# 등을 배우게 될거다!
#
# 결국은 딥러닝을 가르치는 수업이 될 것이다!
#
# 딥러닝의 역사?
#
# 딥러닝의 어려움 : 기울기소실문제 <-
# 딥러닝계의 거장 : 힌튼, 르쿤, 요수아 벤지오, 응
#
# 요수아 벤지오가 만든 씨아노 210 (17년까지 개발)
# Caffe (사장)
# DL4J (사장)
# torch3 (사장)
#
# 2015 : 텐서플로우 (구글) / 컴공과가 사용하기 편함
# 2015 : 케라스 (프랑소와 숄레) (케라스가 텐서플로우로 들어감 잘 안 섞임)
#
# 케라스를 쓰는 이유 ,,
# 접근성이 높고 생산성이 높다 ,, -> 즉 비 전공자들이 사용하기 매우 편함
#
# 파이토치 + fastai(케라스랑 비슷한걸 만듬)
#
# 파이토치가 나만의 모델을 만들기 쉽다. 사용하기 좀 편해~
#
# fastai
#
# - 파이토치 기반의 프레임워크
# - 모델의 사용이 쉽다. (케라스보다 더 쉬움)
# - 지원되는 모델이 케라스보단 적음
# - fastai 보다 더 깊은 수준의 프로그래밍 능력을 요구할 때 (fastai에 없는 함수) 파이토치로 스무스하게 넘어갈 수 있다.

# %% [markdown]
# 파이썬 - 파이토치를 사용할 것이다. (페이스북)
#
# 파이토치 중 fastai라는 모듈을 주로 사용할 것이다.
#
# https://github.com/fastai/fastbook 참고 교재!
#
# ![image.png](attachment:bd6ce5a6-70c8-4e45-8ca8-7f62d282ddb8.png)
#
# ㄴ 한글 번역판이 나왔는데 아주 좋은 ,, 교재!!
